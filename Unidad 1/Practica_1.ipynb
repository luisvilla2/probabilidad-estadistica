# %% [markdown]
# <a href="https://colab.research.google.com/github/luisvilla2/probabilidad-estadistica/blob/main/Unidad%201/Practica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![tecno.png](data:image/png;base64,...)
#
# ##Probabilidad y estadistica
#
# Luis Alberto Villalobos Anaya
#
# DR. Jose Gabriel Rivas Rogriguez
#
# grupo 2Z
#
# Practica 1

# %%
from statistics import *
# lista de calificaciones del grupo a de probabilidad y estadistica
grupos = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print(grupos)

type(grupos)

promedio = sum(grupos) / len(grupos)
print(promedio)

promedio2 = mean(grupos)
print(promedio2)

mediana = median(grupos)
print(mediana)

moda = mode(grupos)
print(moda)

moda2 = multimode(grupos)
print(moda2)

tiempos100mts = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.10, 17.20]
print(tiempos100mts)

print("el tiempo promedio de los corredores es=>", mean(tiempos100mts) )

mediana = median(tiempos100mts)
print("la media de los  tiempos de los corredores es=>", mediana )

moda = multimode(tiempos100mts)
print(" la moda de los tiempos es=>", moda)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# 75.33333333333333
# 75.33333333333333
# 76.5
# 70
# [70, 100]
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]
# el tiempo promedio de los corredores es=> 17.322
# la media de los  tiempos de los corredores es=> 17.2
#  la moda de los tiempos es=> [15.1, 17.2]

# %%
#libreria para generar numeros aleatorios
import random

fabrica1= []
for i in range (100):
  numero_aleatorio =round (random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
  print(fabrica1)
# Out:
# [86.17]
# [86.17, 64.51]
# [86.17, 64.51, 61.27]
# [86.17, 64.51, 61.27, 78.54]
# [86.17, 64.51, 61.27, 78.54, 66.0]
# [86.17, 64.51, 61.27, 78.54, 66.0, 74.39]
# [86.17, 64.51, 61.27, 78.54, 66.0, 74.39, 57.09]
# [86.17, 64.51, 61.27, 78.54, 66.0, 74.39, 57.09, 75.14]
# [86.17, 64.51, 61.27, 78.54, 66.0, 74.39, 57.09, 75.14, 52.8]
# [86.17, 64.51, 61.27, 78.54, 66.0, 74.39, 57.09, 75.14, 52.8, 59.86]
# [86.17, 64.51, 61.27, 78.54, 66.0, 74.39, 57.09, 75.14, 52.8, 59.86, 88.77]
# [86.17, 64.51, 61.27, 78.54, 66.0, 74.39, 57.09, 75.14, 52.8, 59.86, 88.77, 53.03]
# [86.17, 64.51, 61.27, 78.54, 66.0, 74.39, 57.09, 75.14, 52.8, 59.86, 88.77, 53.03, 98.73]
# [86.17, 64.51, 61.27, 78.54, 66.0, 74.39, 57.09, 75.14, 52.8, 59.86, 88.77, 53.03, 98.73, 87.01]
# [86.17, 64.51, 61.27, 78.54, 66.0, 74.39, 57.09, 75.14, 52.8, 59.86, 88.77, 53.03, 98.73, 87.01, 50.84]
# [86.17, 64.51, 61.27, 78.54, 66.0, 74.39, 57.09, 75.14, 52.8, 59.86, 88.77, 53.03, 98.73, 87.01, 50.84, 63.52]
# ...

# %%
#libreria para generar numeros aleatorios
import random

fabrica2= []
for i in range (100):
  numero_aleatorio =round (random.uniform(50,100),2)
  fabrica2.append(numero_aleatorio)
  print(fabrica2)
# Out:
# [60.38]
# [60.38, 98.04]
# [60.38, 98.04, 84.67]
# [60.38, 98.04, 84.67, 95.57]
# [60.38, 98.04, 84.67, 95.57, 79.38]
# [60.38, 98.04, 84.67, 95.57, 79.38, 86.07]
# [60.38, 98.04, 84.67, 95.57, 79.38, 86.07, 91.22]
# [60.38, 98.04, 84.67, 95.57, 79.38, 86.07, 91.22, 63.74]
# [60.38, 98.04, 84.67, 95.57, 79.38, 86.07, 91.22, 63.74, 57.02]
# [60.38, 98.04, 84.67, 95.57, 79.38, 86.07, 91.22, 63.74, 57.02, 60.53]
# [60.38, 98.04, 84.67, 95.57, 79.38, 86.07, 91.22, 63.74, 57.02, 60.53, 91.88]
# [60.38, 98.04, 84.67, 95.57, 79.38, 86.07, 91.22, 63.74, 57.02, 60.53, 91.88, 91.03]
# [60.38, 98.04, 84.67, 95.57, 79.38, 86.07, 91.22, 63.74, 57.02, 60.53, 91.88, 91.03, 73.15]
# [60.38, 98.04, 84.67, 95.57, 79.38, 86.07, 91.22, 63.74, 57.02, 60.53, 91.88, 91.03, 73.15, 95.23]
# [60.38, 98.04, 84.67, 95.57, 79.38, 86.07, 91.22, 63.74, 57.02, 60.53, 91.88, 91.03, 73.15, 95.23, 57.9]
# [60.38, 98.04, 84.67, 95.57, 79.38, 86.07, 91.22, 63.74, 57.02, 60.53, 91.88, 91.03, 73.15, 95.23, 57.9, 74.26]
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(fabrica1)
plt.title("produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'produccion diaria de la fabrica 1')

# %%
import matplotlib.pyplot as plt

plt.hist(fabrica2)
plt.title("produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'produccion diaria de la fabrica 2')

# %%
from statistics import *
media1= mean (fabrica1)
mediana1 = median (fabrica1)
moda1 = multimode (fabrica1)
print("Valores de la fabrica 1")
print("la media de la fabrica 1 es=>", media1)
print("la mediana de la fabrica 1 es=>", mediana1)
print("la moda de la fabrica 1 es=>", moda1)
# Out:
# Valores de la fabrica 1
# la media de la fabrica 1 es=> 74.8426
# la mediana de la fabrica 1 es=> 74.12
# la moda de la fabrica 1 es=> [76.06]

# %%
from statistics import *
media2= mean (fabrica2)
mediana2 = median (fabrica2)
moda2 = multimode (fabrica2)
print("Valores de la fabrica 2")
print("la media de la fabrica 2 es=>", media2)
print("la mediana de la fabrica 2 es=>", mediana2)
print("la moda de la fabrica 2 es=>", moda2)
# Out:
# Valores de la fabrica 2
# la media de la fabrica 2 es=> 76.0892
# la mediana de la fabrica 2 es=> 76.02
# la moda de la fabrica 2 es=> [63.58, 95.2]

# %%
fig,(ax1,ax2) = plt.subplots(nrows=1,ncols=2,figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diria de la fabrica 2")
plt.legend()
plt.show()
