# %% [markdown]
# <a href="https://colab.research.google.com/github/luisvilla2/probabilidad-estadistica/blob/main/Unidad%201/Practica_4_y_5_Tabla_de_frecuencias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![tecno.png](data:image/png;base64,...)
#
# ##Probabilidad y estadistica
#
# Luis Alberto Villalobos Anaya
#
# DR. Jose Gabriel Rivas Rogriguez
#
# grupo 2Z
#
# Unidad 1
#
# Practica 4

# %%
import random
#Creamos una lista vacia de 100 personas
edades = []

for i in range (100):
  #ciclo para generar 100 numeros aleatoriosque representan las edades
  numero_aleatorio = random.randint( 18, 70)
  #agregamos ell numero aleatorio a la lista de valores
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [50, 25, 34, 27, 26, 54, 49, 36, 54, 57, 27, 51, 48, 60, 37, 54, 40, 57, 25, 58, 39, 42, 36, 51, 48, 62, 69, 70, 46, 70, 28, 22, 62, 50, 69, 43, 50, 60, 30, 25, 49, 61, 24, 42, 41, 40, 65, 21, 42, 26, 32, 52, 65, 30, 40, 21, 61, 50, 36, 27, 49, 37, 20, 58, 24, 56, 37, 39, 58, 60, 54, 53, 30, 57, 30, 21, 40, 24, 41, 30, 60, 32, 60, 63, 41, 50, 59, 24, 54, 34, 19, 33, 65, 49, 35, 21, 38, 48, 60, 48]

# %%
import pandas as pd
df = pd.DataFrame(edades,columns =['Edad'])
df.head()
# Out:
#    Edad
# 0    50
# 1    25
# 2    34
# 3    27
# 4    26

# %%
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad','Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')
print("Tabla de la Distribucion de frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de la Distribucion de frecuencias:
#     Edad  Frecuencia
# 28    19           1
# 35    20           1
# 5     21           4
# 38    22           1
# 7     24           4
# 11    25           3
# 26    26           2
# 15    27           3
# 39    28           1
# 3     30           5
# 22    32           2
# 29    33           1
# 23    34           2
# 30    35           1
# 17    36           3
# 14    37           3
# 40    38           1
# 24    39           2
# 4     40           4
# 10    41           3
# 13    42           3
# 37    43           1
# 33    46           1
# 8     48           4
# 6     49           4
# 1     50           5
# 21    51           2
# 36    52           1
# 31    53           1
# 2     54           5
# 34    56           1
# 16    57           3
# 12    58           3
# 27    59           1
# 0     60           6
# 25    61           2
# 18    62           2
# 32    63           1
# 9     65           3
# 19    69           2
# 20    70           2

# %%
tabla_frecuencias['Frec relativa'] = tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa
# 28    19           1           0.01
# 35    20           1           0.01
# 5     21           4           0.04
# 38    22           1           0.01
# 7     24           4           0.04
# 11    25           3           0.03
# 26    26           2           0.02
# 15    27           3           0.03
# 39    28           1           0.01
# 3     30           5           0.05
# 22    32           2           0.02
# 29    33           1           0.01
# 23    34           2           0.02
# 30    35           1           0.01
# 17    36           3           0.03
# 14    37           3           0.03
# 40    38           1           0.01
# 24    39           2           0.02
# 4     40           4           0.04
# 10    41           3           0.03
# 13    42           3           0.03
# 37    43           1           0.01
# 33    46           1           0.01
# 8     48           4           0.04
# 6     49           4           0.04
# 1     50           5           0.05
# 21    51           2           0.02
# 36    52           1           0.01
# 31    53           1           0.01
# 2     54           5           0.05
# 34    56           1           0.01
# 16    57           3           0.03
# 12    58           3           0.03
# 27    59           1           0.01
# 0     60           6           0.06
# 25    61           2           0.02
# 18    62           2           0.02
# 32    63           1           0.01
# 9     65           3           0.03
# 19    69           2           0.02
# 20    70           2           0.02

# %%
tabla_frecuencias['Frec porcentual'] = tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa  Frec porcentual
# 28    19           1           0.01             0.01
# 35    20           1           0.01             0.01
# 5     21           4           0.04             0.04
# 38    22           1           0.01             0.01
# 7     24           4           0.04             0.04
# 11    25           3           0.03             0.03
# 26    26           2           0.02             0.02
# 15    27           3           0.03             0.03
# 39    28           1           0.01             0.01
# 3     30           5           0.05             0.05
# 22    32           2           0.02             0.02
# 29    33           1           0.01             0.01
# 23    34           2           0.02             0.02
# 30    35           1           0.01             0.01
# 17    36           3           0.03             0.03
# 14    37           3           0.03             0.03
# 40    38           1           0.01             0.01
# 24    39           2           0.02             0.02
# 4     40           4           0.04             0.04
# 10    41           3           0.03             0.03
# 13    42           3           0.03             0.03
# 37    43           1           0.01             0.01
# 33    46           1           0.01             0.01
# 8     48           4           0.04             0.04
# 6     49           4           0.04             0.04
# 1     50           5           0.05             0.05
# 21    51           2           0.02             0.02
# 36    52           1           0.01             0.01
# 31    53           1           0.01             0.01
# 2     54           5           0.05             0.05
# 34    56           1           0.01             0.01
# 16    57           3           0.03             0.03
# 12    58           3           0.03             0.03
# 27    59           1           0.01             0.01
# 0     60           6           0.06             0.06
# 25    61           2           0.02             0.02
# 18    62           2           0.02             0.02
# 32    63           1           0.01             0.01
# 9     65           3           0.03             0.03
# 19    69           2           0.02             0.02
# 20    70           2           0.02             0.02

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia']. cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa  Frec porcentual  Frec Acumulada
# 28    19           1           0.01             0.01               1
# 35    20           1           0.01             0.01               2
# 5     21           4           0.04             0.04               6
# 38    22           1           0.01             0.01               7
# 7     24           4           0.04             0.04              11
# 11    25           3           0.03             0.03              14
# 26    26           2           0.02             0.02              16
# 15    27           3           0.03             0.03              19
# 39    28           1           0.01             0.01              20
# 3     30           5           0.05             0.05              25
# 22    32           2           0.02             0.02              27
# 29    33           1           0.01             0.01              28
# 23    34           2           0.02             0.02              30
# 30    35           1           0.01             0.01              31
# 17    36           3           0.03             0.03              34
# 14    37           3           0.03             0.03              37
# 40    38           1           0.01             0.01              38
# 24    39           2           0.02             0.02              40
# 4     40           4           0.04             0.04              44
# 10    41           3           0.03             0.03              47
# 13    42           3           0.03             0.03              50
# 37    43           1           0.01             0.01              51
# 33    46           1           0.01             0.01              52
# 8     48           4           0.04             0.04              56
# 6     49           4           0.04             0.04              60
# 1     50           5           0.05             0.05              65
# 21    51           2           0.02             0.02              67
# 36    52           1           0.01             0.01              68
# 31    53           1           0.01             0.01              69
# 2     54           5           0.05             0.05              74
# 34    56           1           0.01             0.01              75
# 16    57           3           0.03             0.03              78
# 12    58           3           0.03             0.03              81
# 27    59           1           0.01             0.01              82
# 0     60           6           0.06             0.06              88
# 25    61           2           0.02             0.02              90
# 18    62           2           0.02             0.02              92
# 32    63           1           0.01             0.01              93
# 9     65           3           0.03             0.03              96
# 19    69           2           0.02             0.02              98
# 20    70           2           0.02             0.02             100

# %%
#Libreria para calculos matematicos
import math
print (edades)
# Out:
# [50, 25, 34, 27, 26, 54, 49, 36, 54, 57, 27, 51, 48, 60, 37, 54, 40, 57, 25, 58, 39, 42, 36, 51, 48, 62, 69, 70, 46, 70, 28, 22, 62, 50, 69, 43, 50, 60, 30, 25, 49, 61, 24, 42, 41, 40, 65, 21, 42, 26, 32, 52, 65, 30, 40, 21, 61, 50, 36, 27, 49, 37, 20, 58, 24, 56, 37, 39, 58, 60, 54, 53, 30, 57, 30, 21, 40, 24, 41, 30, 60, 32, 60, 63, 41, 50, 59, 24, 54, 34, 19, 33, 65, 49, 35, 21, 38, 48, 60, 48]

# %%
#generar un nuevo dataFrame con las edades
import pandas as pd
df = pd.DataFrame({'Edad':edades})
df
# Out:
#     Edad
# 0     50
# 1     25
# 2     34
# 3     27
# 4     26
# ..   ...
# 95    21
# 96    38
# 97    48
# 98    60
# 99    48
#
# [100 rows x 1 columns]

# %%
n = len (edades)
k = int (1 + math.log2(100))
print ("Valor de n = ",n, "\nNumero de intervalos =",k)
# Out:
# Valor de n =  100
# Numero de intervalos = 7

# %%
tabla_frecuencias = pd.cut (df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns = ['clase','frec']
tabla_frecuencias
# Out:
#               clase  frec
# 0  (48.143, 55.429]    18
# 1  (55.429, 62.714]    18
# 2  (18.948, 26.286]    16
# 3  (33.571, 40.857]    16
# 4  (26.286, 33.571]    12
# 5  (40.857, 48.143]    12
# 6    (62.714, 70.0]     8

# %%
tabla_frecuencias = tabla_frecuencias.sort_values( by='clase')
tabla_frecuencias
# Out:
#               clase  frec
# 2  (18.948, 26.286]    16
# 4  (26.286, 33.571]    12
# 3  (33.571, 40.857]    16
# 5  (40.857, 48.143]    12
# 0  (48.143, 55.429]    18
# 1  (55.429, 62.714]    18
# 6    (62.714, 70.0]     8

# %%
tabla_frecuencias['frec Rel']= tabla_frecuencias['frec']/n
tabla_frecuencias['frec Porc']= tabla_frecuencias['frec']/n* 100
tabla_frecuencias['frec Ac']= tabla_frecuencias['frec'].cumsum()
tabla_frecuencias['frec Rel Ac']= tabla_frecuencias['frec Porc'].cumsum()
tabla_frecuencias['frec Porc Ac']= tabla_frecuencias['frec Porc'].cumsum()
print("Tabla de frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de frecuencias:
#               clase  frec  frec Rel  frec Porc  frec Ac  frec Rel Ac  \
# 2  (18.948, 26.286]    16      0.16       16.0       16         16.0
# 4  (26.286, 33.571]    12      0.12       12.0       28         28.0
# 3  (33.571, 40.857]    16      0.16       16.0       44         44.0
# 5  (40.857, 48.143]    12      0.12       12.0       56         56.0
# 0  (48.143, 55.429]    18      0.18       18.0       74         74.0
# 1  (55.429, 62.714]    18      0.18       18.0       92         92.0
# 6    (62.714, 70.0]     8      0.08        8.0      100        100.0
#
#    frec Porc Ac
# 2          16.0
# 4          28.0
# 3          44.0
# 5          56.0
# 0          74.0
# 1          92.0
# 6         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades,alpha=0.5,bins=20)
plt.title("Histrograma de edades basado en la funcion de matplotib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histrograma de edades basado en la funcion de matplotib con valores estandar')

# %%
plt.hist(df['Edad'],bins=k,alpha=0.5)
plt.title('Histograma de edades basado en la regla de sturges')
plt.xlabel('edades')
plt.xlabel('frecuencia')
# Out:
# Text(0.5, 0, 'frecuencia')

# %% [markdown]
# PRACTICA 5 DIAGRAMA DE CAJAS Y BIGOTES

# %%
#Creamos una lista vacia de 100 personas
edades2 = []

for i in range (100):
  #ciclo para generar 100 numeros aleatoriosque representan las edades
  numero_aleatorio = random.randint( 20, 87)
  #agregamos ell numero aleatorio a la lista de valores
  edades2.append(numero_aleatorio)
print(edades2)
# Out:
# [69, 56, 41, 59, 36, 71, 61, 44, 75, 52, 70, 56, 37, 32, 69, 44, 85, 32, 31, 27, 71, 82, 84, 53, 36, 80, 61, 62, 34, 82, 53, 69, 37, 38, 72, 22, 65, 54, 78, 33, 42, 48, 71, 52, 33, 38, 64, 45, 85, 30, 30, 31, 43, 42, 59, 47, 48, 79, 24, 51, 29, 58, 57, 50, 28, 54, 77, 47, 59, 72, 77, 45, 38, 83, 54, 79, 53, 37, 43, 52, 35, 21, 21, 36, 45, 84, 63, 56, 45, 78, 58, 32, 38, 36, 82, 48, 40, 21, 59, 63]

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('Edades Encuesta 2')
plt.show()

# %%
edades2.append(130)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('Edades Encuesta 2')
plt.show()
